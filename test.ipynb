# %%
import numpy as np
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier

# %%
d16=pd.read_csv('raw_data/2016-17.csv').set_index('full_name')
d17=pd.read_csv('raw_data/2017-18.csv').set_index('full_name').drop('now_cost',1)
d18=pd.read_csv('raw_data/2018-19.csv').set_index('full_name').drop('now_cost',1)
d19=pd.read_csv('raw_data/2019-20.csv').set_index('full_name').drop('now_cost',1)

# %%
for n in d16.index:
    if n not in d17.index:
        d16.drop(n,0,inplace=True)
        
for n in d17.index:
    if n not in d16.index:
        d17.drop(n,0,inplace=True)

# %%
for n in d18.index:
    if n not in d19.index:
        d18.drop(n,0,inplace=True)
        
for n in d19.index:
    if n not in d18.index:
        d19.drop(n,0,inplace=True)

# %%
d18.drop('Danny Ward',inplace=True)

# %%
d19.drop('Danny Ward',inplace=True)

# %%
a=np.array([1,2,3])

# %%
3 in a
# Out:
# True

# %%
d16.sort_values('full_name',inplace=True)
d17.sort_values('full_name',inplace=True)
d18.sort_values('full_name',inplace=True)
d19.sort_values('full_name',inplace=True)

d16.reset_index(inplace=True)
d17.reset_index(inplace=True)
d18.reset_index(inplace=True)
d19.reset_index(inplace=True)

# %%
data1=d16.drop('full_name',1).to_numpy()

# %%
labels1=d17['total_points'].to_numpy()
i=0
while i<len(labels1):
    if labels1[i]<100:
        labels1[i]=0
    else:
        labels1[i]=1
    i+=1

# %%
train_data=data1
train_labels=labels1

# %%
names=d18['full_name'].to_numpy()

# %%
data3=d18.drop('full_name',1).to_numpy()

# %%
labels3=d19['total_points'].to_numpy()
i=0
while i<len(labels3):
    if labels3[i]<100:
        labels3[i]=0
    else:
        labels3[i]=1
    i+=1

# %%
test_data=data3
test_labels=labels3

# %%
model = KNeighborsClassifier(n_neighbors=10)

# %%
model.fit(train_data, train_labels)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#                      weights='uniform')

# %%
predictions = model.predict(test_data)

# %%
perc= sum(predictions == test_labels)/len(test_labels)
perc
# Out:
# 0.8188235294117647

# %%
results=pd.DataFrame()

# %%
results['name']=names
results['actual']=test_labels
results['predicted']=predictions

# %%
results
# Out:
#                                    name  actual  predicted
# 0                       Aaron Cresswell       0          0
# 1                          Aaron Lennon       0          0
# 2                            Aaron Mooy       0          0
# 3                     Aaron Wan-Bissaka       1          0
# 4    Abd-Al-Ali Morakinyo Olaposi Koiki       0          0
# ..                                  ...     ...        ...
# 420                      Yoshinori Muto       0          0
# 421                     Youri Tielemans       1          0
# 422                       Yves Bissouma       0          0
# 423                         Zech Medley       0          0
# 424                      Çaglar Söyüncü       1          0
#
# [425 rows x 3 columns]

# %%
li=[]
for i in results.index:
    if results['predicted'][i]==1 and results['predicted'][i]== results['actual'][i]:
        li.append(results['name'][i])

# %%
final=pd.DataFrame()

# %%
for i in d19.index:
    if d19['full_name'][i] in li:
        final.append(d19.loc[i])

# %%
final
# Out:
#                                      19           48   \
# full_name            Alexandre Lacazette  Ayoze Pérez
# goals_scored                          10            8
# assists                                7            5
# total_points                           1            1
# minutes                             1867         1998
# goals_conceded                        25           25
# creativity                         337.7        443.9
# influence                          536.4        547.4
# threat                               861          779
# bonus                                 16            9
# bps                                  387          402
# ict_index                          173.8        177.3
# clean_sheets                           5            9
# red_cards                              0            0
# yellow_cards                           8            0
# selected_by_percent                  2.4            5
#
#                                                          61          62   \
# full_name            Bernardo Mota Veiga de Carvalho e Silva  Bernd Leno
# goals_scored                                               6           0
# assists                                                    7           0
# total_points                                               1           1
# minutes                                                 2021        2649
# goals_conceded                                            24          39
# creativity                                             773.2           0
# influence                                              626.2       843.2
# threat                                                   927           0
# bonus                                                      7          10
# bps                                                      526         591
# ict_index                                              232.5        84.1
# clean_sheets                                               9           7
# red_cards                                                  0           0
# yellow_cards                                               5           2
# selected_by_percent                                      8.1         4.2
#
#                                66           105             182          189  \
# full_name            Callum Wilson  David Silva  James Maddison  Jamie Vardy
# goals_scored                     8            6               6           23
# assists                          6           12               5            7
# total_points                     1            1               1            1
# minutes                       2906         1821            2624         3032
# goals_conceded                  53           15              26           38
# creativity                   391.1        735.8          1246.4        418.4
# influence                    397.4        639.6           642.4         1026
# threat                         848          937             702         1455
# bonus                            8           15              14           34
# bps                            321          549             548          775
# ict_index                    162.6        231.2           259.2        288.8
# clean_sheets                     4           11              10           11
# red_cards                        0            0               0            0
# yellow_cards                     9            0               4            3
# selected_by_percent            4.2          9.1            12.1         27.2
#
#                                298                        332  \
# full_name            Mohamed Salah  Pierre-Emerick Aubameyang
# goals_scored                    19                         22
# assists                         10                          5
# total_points                     1                          1
# minutes                       2879                       3136
# goals_conceded                  26                         44
# creativity                   834.8                      479.6
# influence                   1061.2                       1006
# threat                        2156                       1369
# bonus                           26                         37
# bps                            661                        807
# ict_index                    405.1                      285.2
# clean_sheets                    16                         10
# red_cards                        0                          1
# yellow_cards                     1                          3
# selected_by_percent           32.4                       22.4
#
#                                  337                     341         362  \
# full_name            Raheem Sterling  Richarlison de Andrade  Sadio Mané
# goals_scored                      20                      13          18
# assists                            6                       5          10
# total_points                       1                       1           1
# minutes                         2651                    3070        2745
# goals_conceded                    31                      51          28
# creativity                     751.3                   478.1       826.6
# influence                      921.6                   814.6      1010.2
# threat                          1829                    1233        1239
# bonus                             20                      13          27
# bps                              642                     519         689
# ict_index                      350.2                   252.3       307.7
# clean_sheets                      13                       9          12
# red_cards                          0                       0           0
# yellow_cards                       5                       8           3
# selected_by_percent             23.2                     9.2        19.7
#
#                                         396          397            410
# full_name            Trent Alexander-Arnold  Troy Deeney  Wilfried Zaha
# goals_scored                              4           10              4
# assists                                  15            2              6
# total_points                              1            1              1
# minutes                                3173         2224           3279
# goals_conceded                           32           39             46
# creativity                           1380.3        378.5            588
# influence                            1026.8          536            572
# threat                                  420          801           1103
# bonus                                    24           15              4
# bps                                     904          403            337
# ict_index                             282.8        171.4          226.4
# clean_sheets                             14            6              9
# red_cards                                 0            0              0
# yellow_cards                              5            3              5
# selected_by_percent                    39.1          1.7            8.4
